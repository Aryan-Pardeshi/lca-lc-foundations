# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class ColourContext:
    favourite_colour: str = "blue"
    least_favourite_colour: str = "yellow"

# %%
from langchain.agents import create_agent
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
agent = create_agent(
    model=model,
    context_schema=ColourContext  
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='440ca331-33f6-4f85-a960-9bfe20c940ff'),
#               AIMessage(content='I do not have access to your personal information, including your favorite color. I am a large language model, and I am not able to access any data about you. \n\nTo tell me your favorite color, you can simply tell me!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cf0cb-bdce-7fb2-81e1-7832ca1eb05f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 49, 'total_tokens': 56, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ## Accessing Context

# %%
from langchain.tools import tool, ToolRuntime

@tool
def get_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour

@tool
def get_least_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour

# %%
agent = create_agent(
    model=model,
    tools=[get_favourite_colour, get_least_favourite_colour],
    context_schema=ColourContext
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

pprint(response)
# Out:
# c:\Users\admin\Desktop\Aryan\Python\Langchain Acadamy\lca-lc-foundations\.venv\Lib\site-packages\pydantic\main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='7e38bdcd-022c-4c1e-bdbd-4e62e901710d'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_favourite_colour', 'arguments': '{}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cf0cc-fa5c-7fd2-b86f-797df6839cbe-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': '6579f99d-7a55-4675-8bfd-07e34da190d1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 72, 'output_tokens': 13, 'total_tokens': 85, 'input_token_details': {'cache_read': 0}}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='7bda09c2-8db2-4376-b075-4878862a30c0', tool_call_id='6579f99d-7a55-4675-8bfd-07e34da190d1'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cf0cc-fe6c-7720-b253-c4ee8c4912a6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 103, 'output_tokens': 0, 'total_tokens': 103, 'input_token_details': {'cache_read': 0}})]}

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext(favourite_colour="green")
)

pprint(response)
# Out:
# c:\Users\admin\Desktop\Aryan\Python\Langchain Acadamy\lca-lc-foundations\.venv\Lib\site-packages\pydantic\main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='61d4db97-d2e4-4882-a92f-07e7e6e5db0b'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_favourite_colour', 'arguments': '{}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cf0cf-d295-7b80-84f0-2f9f0bbb65bc-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'df5c6892-ea96-4ed4-8760-b14be9364fc5', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 72, 'output_tokens': 13, 'total_tokens': 85, 'input_token_details': {'cache_read': 0}}),
#               ToolMessage(content='green', name='get_favourite_colour', id='23fb9bbd-9880-4097-ae36-b9f4b1f936af', tool_call_id='df5c6892-ea96-4ed4-8760-b14be9364fc5'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cf0cf-d68e-7bc3-97f9-87b03d9e6f71-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 103, 'output_tokens': 0, 'total_tokens': 103, 'input_token_details': {'cache_read': 0}})]}
