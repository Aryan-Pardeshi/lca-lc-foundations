# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
agent = create_agent(
    model=model,
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st 2026")]},
    config
    )
# Out:
# Key 'additionalProperties' is not supported in schema, ignoring
# Key '$schema' is not supported in schema, ignoring
# Key 'additionalProperties' is not supported in schema, ignoring
# Key '$schema' is not supported in schema, ignoring
# Key 'additionalProperties' is not supported in schema, ignoring
# Key '$schema' is not supported in schema, ignoring
# Key 'additionalProperties' is not supported in schema, ignoring
# Key '$schema' is not supported in schema, ignoring

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='33fa194c-cd25-4992-bdd6-d65d6a40d429'),
#               AIMessage(content='I can help you with that!\n\nPlease, specify the year for your flight search.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cf0c3-3f48-7e90-b284-c17b61a21f2e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1211, 'output_tokens': 18, 'total_tokens': 1229, 'input_token_details': {'cache_read': 0}}),
#               HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st 2026', additional_kwargs={}, response_metadata={}, id='776ade8f-9ef7-4f83-a4bb-4871075490c4'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'search-flight', 'arguments': '{"flyTo": "Tokyo", "departureDate": "31/03/2026", "flyFrom": "San Francisco"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cf0c7-2562-7622-8a18-4be7162ff0b1-0', tool_calls=[{'name': 'search-flight', 'args': {'flyTo': 'Tokyo', 'departureDate': '31/03/2026', 'flyFrom': 'San Francisco'}, 'id': 'e9cee256-8110-445c-baad-4476dcc5300e', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1252, 'output_tokens': 38, 'total_tokens': 1290, 'input_token_details': {'cache_read': 0}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:25:00.000Z",\n      "local": "2026-03-31T00:25:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T03:25:00.000Z",\n      "local": "2026-04-01T12:25:00.000"\n    },\n    "totalDurationInSeconds": 72000,\n    "durationInSeconds": 72000,\n    "price": 596,\n    "deepLink": "https://on.kiwi.com/nDPtbG",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:15:00.000Z",\n          "local": "2026-04-01T05:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-03-31T23:55:00.000Z",\n          "local": "2026-04-01T07:55:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:25:00.000Z",\n      "local": "2026-03-31T00:25:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T04:25:00.000Z",\n      "local": "2026-04-01T13:25:00.000"\n    },\n    "totalDurationInSeconds": 75600,\n    "durationInSeconds": 75600,\n    "price": 596,\n    "deepLink": "https://on.kiwi.com/3CVJ4b",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:15:00.000Z",\n          "local": "2026-04-01T05:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T01:00:00.000Z",\n          "local": "2026-04-01T09:00:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T03:25:00.000Z",\n      "local": "2026-04-01T12:25:00.000"\n    },\n    "totalDurationInSeconds": 70500,\n    "durationInSeconds": 70500,\n    "price": 596,\n    "deepLink": "https://on.kiwi.com/5Cudsj",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:40:00.000Z",\n          "local": "2026-04-01T05:40:00.000"\n        },\n        "departure": {\n          "utc": "2026-03-31T23:55:00.000Z",\n          "local": "2026-04-01T07:55:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T04:25:00.000Z",\n      "local": "2026-04-01T13:25:00.000"\n    },\n    "totalDurationInSeconds": 74100,\n    "durationInSeconds": 74100,\n    "price": 596,\n    "deepLink": "https://on.kiwi.com/AQeU8E",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:40:00.000Z",\n          "local": "2026-04-01T05:40:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T01:00:00.000Z",\n          "local": "2026-04-01T09:00:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "HND",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T07:10:00.000Z",\n      "local": "2026-04-01T16:10:00.000"\n    },\n    "totalDurationInSeconds": 84000,\n    "durationInSeconds": 84000,\n    "price": 741,\n    "deepLink": "https://on.kiwi.com/ ...
#               AIMessage(content='I found a few flight options for you. It seems that all direct flights from San Francisco to Tokyo on March 31st, 2026, have layovers.\n\nHere are some options:\n\n| Route(s)                                    | Departure & Arrival (Local Time)           | Cabin Class | Return Route(s) | Return Departure & Arrival (Local Time) | Return Cabin Class | Price | Booking Link |\n| :------------------------------------------ | :----------------------------------------- | :---------- | :-------------- | :-------------------------------------- | :----------------- | :---- | :----------- |\n| SFO → NRT (via TPE)                         | 03/31 00:25 → 04/01 12:25 (20h 0m)          | Economy     | N/A             | N/A                                     | N/A                | 596€  | [Link](https://on.kiwi.com/nDPtbG) |\n| SFO → NRT (via TPE)                         | 03/31 00:25 → 04/01 13:25 (21h 0m)          | Economy     | N/A             | N/A                                     | N/A                | 596€  | [Link](https://on.kiwi.com/3CVJ4b) |\n| SFO → NRT (via TPE)                         | 03/31 00:50 → 04/01 12:25 (19h 35m)         | Economy     | N/A             | N/A                                     | N/A                | 596€  | [Link](https://on.kiwi.com/5Cudsj) |\n| SFO → NRT (via TPE)                         | 03/31 00:50 → 04/01 13:25 (20h 35m)         | Economy     | N/A             | N/A                                     | N/A                | 596€  | [Link](https://on.kiwi.com/AQeU8E) |\n| SFO → HND (via TPE, KIX)                    | 03/31 00:50 → 04/01 16:10 (22h 20m)         | Economy     | N/A             | N/A                                     | N/A                | 741€  | [Link](https://on.kiwi.com/L3K9DO) |\n| SFO → NRT (via TPE)                         | 03/31 01:05 → 04/01 16:35 (22h 30m)         | Economy     | N/A             | N/A                                     | N/A                | 752€  | [Link](https://on.kiwi.com/nC418h) |\n| SFO → NRT                                   | 03/31 11:40 → 04/01 15:00 (11h 20m)         | Economy     | N/A             | N/A                                     | N/A                | 763€  | [Link](https://on.kiwi.com/Zh7iJw) |\n| SFO → NRT                                   | 03/31 11:40 → 04/01 15:00 (11h 20m)         | Economy     | N/A             | N/A                                     | N/A                | 793€  | [Link](https://on.kiwi.com/ZO0NqN) |\n| SFO → NRT                                   | 03/31 12:20 → 04/01 15:25 (11h 5m)          | Economy     | N/A             | N/A                                     | N/A                | 1177€ | [Link](https://on.kiwi.com/xQXpef) |\n| SFO → NRT                                   | 03/31 12:20 → 04/01 15:25 (11h 5m)          | Economy     | N/A             | N/A                                     | N/A                | 1219€ | [Link](https://on.kiwi.com/CfJPXC) |\n| SFO → NRT (via TPE, OKA)                    | 03/31 12:30 → 04/02 14:55 (30h 25m)         | Economy     | N/A             | N/A                                     | N/A                | 642€  | [Link](https://on.kiwi.com/mO9HZo) |\n| SFO → NRT (via DOH)                         | 03/31 15:55 → 04/02 12:55 (30h 0m)          | Economy     | N/A             | N/A                                     | N/A                | 1088€ | [Link](https://on.kiwi.com/HqLpu6) |\n| SFO → NRT (via DOH)                         | 03/31 15:55 → 04/02 19:10 (32h 15m)         | Economy     | N/A             | N/A                                     | N/A                | 1088€ | [Link](https://on.kiwi.com/WC8BCj) |\n| SFO → NRT                                   | 03/31 16:45 → 04/01 20:00 (11h 15m)         | Economy     | N/A             | N/A                                     | N/A                | 688€  | [Link](https://on.kiwi.com/8YLElI) |\n| SFO → NRT (via HNL)                         | 03/31 18:36 → 04/02 16:25 (21h 49m)       ...

# %%
print(response["messages"][-1].content)
# Out:
# I found a few flight options for you. It seems that all direct flights from San Francisco to Tokyo on March 31st, 2026, have layovers.
#
# Here are some options:
#
# | Route(s)                                    | Departure & Arrival (Local Time)           | Cabin Class | Return Route(s) | Return Departure & Arrival (Local Time) | Return Cabin Class | Price | Booking Link |
# | :------------------------------------------ | :----------------------------------------- | :---------- | :-------------- | :-------------------------------------- | :----------------- | :---- | :----------- |
# | SFO → NRT (via TPE)                         | 03/31 00:25 → 04/01 12:25 (20h 0m)          | Economy     | N/A             | N/A                                     | N/A                | 596€  | [Link](https://on.kiwi.com/nDPtbG) |
# | SFO → NRT (via TPE)                         | 03/31 00:25 → 04/01 13:25 (21h 0m)          | Economy     | N/A             | N/A                                     | N/A                | 596€  | [Link](https://on.kiwi.com/3CVJ4b) |
# | SFO → NRT (via TPE)                         | 03/31 00:50 → 04/01 12:25 (19h 35m)         | Economy     | N/A             | N/A                                     | N/A                | 596€  | [Link](https://on.kiwi.com/5Cudsj) |
# | SFO → NRT (via TPE)                         | 03/31 00:50 → 04/01 13:25 (20h 35m)         | Economy     | N/A             | N/A                                     | N/A                | 596€  | [Link](https://on.kiwi.com/AQeU8E) |
# | SFO → HND (via TPE, KIX)                    | 03/31 00:50 → 04/01 16:10 (22h 20m)         | Economy     | N/A             | N/A                                     | N/A                | 741€  | [Link](https://on.kiwi.com/L3K9DO) |
# | SFO → NRT (via TPE)                         | 03/31 01:05 → 04/01 16:35 (22h 30m)         | Economy     | N/A             | N/A                                     | N/A                | 752€  | [Link](https://on.kiwi.com/nC418h) |
# | SFO → NRT                                   | 03/31 11:40 → 04/01 15:00 (11h 20m)         | Economy     | N/A             | N/A                                     | N/A                | 763€  | [Link](https://on.kiwi.com/Zh7iJw) |
# | SFO → NRT                                   | 03/31 11:40 → 04/01 15:00 (11h 20m)         | Economy     | N/A             | N/A                                     | N/A                | 793€  | [Link](https://on.kiwi.com/ZO0NqN) |
# | SFO → NRT                                   | 03/31 12:20 → 04/01 15:25 (11h 5m)          | Economy     | N/A             | N/A                                     | N/A                | 1177€ | [Link](https://on.kiwi.com/xQXpef) |
# | SFO → NRT                                   | 03/31 12:20 → 04/01 15:25 (11h 5m)          | Economy     | N/A             | N/A                                     | N/A                | 1219€ | [Link](https://on.kiwi.com/CfJPXC) |
# | SFO → NRT (via TPE, OKA)                    | 03/31 12:30 → 04/02 14:55 (30h 25m)         | Economy     | N/A             | N/A                                     | N/A                | 642€  | [Link](https://on.kiwi.com/mO9HZo) |
# | SFO → NRT (via DOH)                         | 03/31 15:55 → 04/02 12:55 (30h 0m)          | Economy     | N/A             | N/A                                     | N/A                | 1088€ | [Link](https://on.kiwi.com/HqLpu6) |
# | SFO → NRT (via DOH)                         | 03/31 15:55 → 04/02 19:10 (32h 15m)         | Economy     | N/A             | N/A                                     | N/A                | 1088€ | [Link](https://on.kiwi.com/WC8BCj) |
# | SFO → NRT                                   | 03/31 16:45 → 04/01 20:00 (11h 15m)         | Economy     | N/A             | N/A                                     | N/A                | 688€  | [Link](https://on.kiwi.com/8YLElI) |
# | SFO → NRT (via HNL)                         | 03/31 18:36 → 04/02 16:25 (21h 49m)         | Economy     | N/A             | N/A                                     | N/A                | 717€  | [Link](https://on.kiwi.com/D46RcW) |
#
# The cheapest flight is 596€ and the shortest flight is 11h 20m.
#
# I recommend the flight from SFO to NRT for 596€ with a layover in Taipei, as it offers a good balance of price and duration.
#
# Have a nice trip to Tokyo!
#
# Fun fact: Tokyo is the most populous metropolitan area in the world, with over 37 million residents.
