# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

# model = init_chat_model(model="gpt-5-nano")

from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content="That's a fun question! The Moon doesn't have a capital city. It's a celestial body, not a country or a populated planet with governments and cities.\n\nSo, while we might imagine a lunar capital, in reality, there isn't one.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ceb4f-f5bd-76c2-aee6-b120f8412e51-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 56, 'total_tokens': 66, 'input_token_details': {'cache_read': 0}})

# %%
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city. It's a celestial body, not a country or a populated planet with governments and cities.
#
# So, while we might imagine a lunar capital, in reality, there isn't one.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash-lite',
#  'model_provider': 'google_genai',
#  'safety_ratings': []}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question that plays on our understanding of what a "capital" is!
#
# Since the Moon doesn't have any countries, governments, or permanent human settlements in the way Earth does, it **does not have a capital city**.
#
# However, if we were to imagine a hypothetical future where humans colonize the Moon and establish a capital, it would be entirely up to them to decide where that would be!

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

# agent = create_agent(model=model)

# %%
google_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
agent = create_agent(model=google_model)

# %%
# agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='2b5ce4c9-f696-4c7d-bccb-a2f350c4481c'),
#               AIMessage(content='That\'s a fun question! The Moon doesn\'t have a capital city like Earth does. It\'s a celestial body with no permanent human settlements or governments.\n\nHowever, if we were to imagine a "capital" based on historical significance and human activity, some might jokingly suggest:\n\n*   **Tranquility Base:** This is where Neil Armstrong and Buzz Aldrin first landed in 1969 during the Apollo 11 mission. It\'s a very significant spot in human history.\n\nBut in reality, the Moon remains a wild and beautiful place without any cities, let alone a capital!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ceb58-bdec-78d3-ac01-f3dba2a806bc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 126, 'total_tokens': 136, 'input_token_details': {'cache_read': 0}})]}

# %%
print(response['messages'][-1].content)
# Out:
# That's a fun question! The Moon doesn't have a capital city like Earth does. It's a celestial body with no permanent human settlements or governments.
#
# However, if we were to imagine a "capital" based on historical significance and human activity, some might jokingly suggest:
#
# *   **Tranquility Base:** This is where Neil Armstrong and Buzz Aldrin first landed in 1969 during the Apollo 11 mission. It's a very significant spot in human history.
#
# But in reality, the Moon remains a wild and beautiful place without any cities, let alone a capital!

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='3aba3225-a474-4d00-8f3d-c1f4b14af8bf'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='2484d563-943f-424d-8857-d76e210dd73f', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='a5a438bb-45e1-4042-b767-999055c314b6'),
#               AIMessage(content="Luna City is a fictional city on the Moon. It has been featured in various works of science fiction, including novels, films, and video games. In these stories, Luna City is often depicted as a major hub for lunar colonization, a center of scientific research, or a bustling metropolis with a unique culture shaped by its extraterrestrial environment.\n\nSome common themes associated with Luna City in fiction include:\n\n*   **Advanced Technology:** Due to its location and the need for survival, Luna City is often portrayed with cutting-edge technology for life support, transportation, and resource management.\n*   **Unique Architecture:** Buildings might be designed to withstand the vacuum of space, low gravity, and radiation, potentially featuring domes, underground structures, or structures made of lunar materials.\n*   **Diverse Population:** It could be home to people from all over Earth, or even other alien species, creating a melting pot of cultures and ideas.\n*   **Challenges of Lunar Life:** Stories might explore the psychological and physical challenges of living in a low-gravity, enclosed environment, or the political and economic complexities of a lunar society.\n*   **A Base for Exploration:** Luna City often serves as a staging ground for further space exploration, both within the solar system and beyond.\n\n**It's important to remember that Luna City is purely fictional.** There is currently no city, nor any permanent human settlement, on the Moon. The Moon is still a place of scientific exploration, with robotic missions and occasional human visits (like the Apollo missions).\n\nIf you've encountered Luna City in a specific story, knowing that context would help me tell you more about its portrayal in that particular work!", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ceb5a-e8e4-7b90-97b1-69dc7944aec5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 29, 'output_tokens': 341, 'total_tokens': 370, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City, the capital of the Moon, is a testament to humanity's ambition and ingenuity. It's a place that exists in the realm of science fiction, a dream that has captivated imaginations for generations. While it doesn't currently exist in reality, we can explore what it *could* be like based on popular portrayals and logical considerations.
#
# Here's a comprehensive look at what Luna City, the capital of the Moon, might entail:
#
# ## Location and Structure:
#
# *   **Crater Cities:** The most common and practical location for Luna City would be within a large, stable lunar crater. This offers natural shielding from micrometeoroids and radiation, as well as potential access to subsurface ice deposits. Popular candidates include Shackleton Crater near the South Pole for its potential water ice and prolonged sunlight.
# *   **Dome Habitats:** The surface of Luna City would likely be covered by massive, transparent, and incredibly strong domes. These domes would create a breathable atmosphere and protect inhabitants from the vacuum of space and the harsh lunar environment. They might be geodesic, or have more complex, multi-layered designs for added resilience.
# *   **Subsurface Expansion:** To maximize protection and utilize lunar resources, much of Luna City would likely be built underground. Tunnels and caverns carved into the lunar regolith would house residential areas, industrial facilities, and research labs, offering superior shielding.
# *   **Modular and Expandable:** Luna City would likely be designed with modularity in mind, allowing for easy expansion as the population and infrastructure grow. Prefabricated modules could be manufactured on Earth or even in lunar orbit and assembled on the Moon.
#
# ## Atmosphere and Environment:
#
# *   **Artificial Atmosphere:** A carefully controlled artificial atmosphere would be essential, mimicking Earth's air composition and pressure. This would require advanced life support systems, recycling of air and water, and robust environmental controls to maintain stable temperatures and humidity.
# *   **Gravity:** The Moon's gravity is about one-sixth of Earth's. While inhabitants would adapt, the long-term effects are unknown. Luna City might incorporate features to mitigate these effects, such as:
#     *   **Centrifugal Gravity Zones:** Rotating sections within the city could simulate higher gravity for health and comfort.
#     *   **Specialized Exercise Facilities:** Advanced gyms and rehabilitation centers would be crucial.
# *   **Lighting:** The domes would allow for natural sunlight to filter through, but artificial lighting would be essential for periods of lunar night and to replicate diurnal cycles. This lighting would likely be optimized for human well-being and plant growth.
# *   **Dust Mitigation:** Lunar dust (regolith) is a significant challenge. It's abrasive, electrically charged, and can get everywhere. Luna City would need sophisticated dust control systems, airlocks, and specialized cleaning technologies.
#
# ## Infrastructure and Technology:
#
# *   **Power Generation:**
#     *   **Solar Power:** Vast solar farms on the lunar surface, especially in areas with prolonged sunlight, would be a primary source.
#     *   **Nuclear Power:** Small, safe, and efficient nuclear reactors would likely be necessary for consistent power, especially during lunar nights.
#     *   **Geothermal (Speculative):** If the Moon has any internal heat, it could be tapped.
# *   **Transportation:**
#     *   **Maglev Trains:** For rapid transit between different sectors of the city.
#     *   **Pressurized Rovers:** For surface exploration and transport outside the city.
#     *   **Elevators and Tunnels:** For efficient movement within the subsurface and between surface and subsurface levels.
#     *   **Personal Mobility Devices:** Small, enclosed vehicles or advanced personal transporters.
# *   **Resource Utilization (ISRU):**
#     *   **Water Ice:** Crucial for drinking water, oxygen production, and rocket propellant.
#     *   **Minerals and Metals:** For construction, manufacturing, and self-sufficiency.
#     *   **Helium-3:** A potential fuel for future fusion reactors.
# *   **Communication:** Advanced satellite networks and direct Earth-Moon communication systems would be vital.
# *   **Waste Management and Recycling:** Extremely efficient systems would be paramount to minimize resource loss and environmental impact.
#
# ## Society and Culture:
#
# *   **Diverse Population:** As a capital, Luna City would likely attract people from all over Earth, bringing a rich tapestry of cultures, languages, and perspectives.
# *   **Unique Lunar Identity:** Over time, a distinct "Lunar" identity would emerge, shaped by the shared experience of living off-world. This could manifest in art, music, fashion, and social customs.
# *   **Governance:** The form of governance would depend on the political structure of the Moon. It could be a federal system with representatives from different lunar settlements, a direct democracy, or even a more centralized authority.
# *   **Education and Research:** Luna City would be a hub for scientific research, particularly in astrophysics, geology, and life sciences. Universities and research institutions would be prominent.
# *   **Economy:** The economy would likely be driven by:
#     *   **Resource Extraction:** Mining of valuable lunar materials.
#     *   **Manufacturing and Engineering:** Building infrastructure and advanced technologies.
#     *   **Tourism:** A unique destination for wealthy individuals from Earth.
#     *   **Scientific Research and Development:** Innovation and intellectual property.
#     *   **Spaceport Operations:** Supporting missions to other parts of the solar system.
# *   **Recreation and Leisure:**
#     *   **Low-Gravity Sports:** Unique athletic pursuits taking advantage of the lunar gravity.
#     *   **Holographic Entertainment:** Immersive virtual reality experiences.
#     *   **Observatories:** Unparalleled views of the cosmos.
#     *   **Parks and Green Spaces:** Carefully curated artificial environments to bring nature indoors.
#     *   **Culinary Innovations:** Adapting Earth cuisine to lunar resources and developing new dishes.
#
# ## Challenges and Considerations:
#
# *   **Psychological Impact:** The isolation, confinement, and constant awareness of being in a hostile environment could take a toll on mental health.
# *   **Health Risks:** Long-term effects of low gravity, radiation exposure, and potential reliance on artificial environments would need constant monitoring and mitigation.
# *   **Dependence on Earth:** Initially, Luna City would be heavily reliant on Earth for supplies and advanced technology. Achieving true self-sufficiency would be a long-term goal.
# *   **Cost and Feasibility:** Establishing and maintaining such a city would be incredibly expensive and require unprecedented technological advancements.
# *   **Terraforming (Long-Term):** While not directly part of Luna City, the dream of terraforming the Moon might influence its development and aspirations.
#
# ## In Popular Culture:
#
# Luna City often appears in science fiction novels, films, and games. These portrayals vary widely, from utopian havens to gritty industrial outposts. Some notable examples include:
#
# *   **"The Moon is a Harsh Mistress" by Robert A. Heinlein:** Depicts a lunar colony rebelling against Earth.
# *   **"2001: A Space Odyssey" by Arthur C. Clarke:** Features a lunar base and research facility.
# *   **Various video games:** Often feature lunar bases or cities as explorable environments.
#
# **In conclusion, Luna City, the capital of the Moon, is a captivating concept that embodies humanity's drive to explore and settle beyond Earth. It represents a future where we not only visit but also live and thrive in the vastness of space, a testament to our enduring spirit of innovation and our dreams of a multi-planetary existence.**
