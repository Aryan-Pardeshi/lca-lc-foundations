# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

google_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model=google_model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way that countries on Earth do. It's a celestial body without any established governments or permanent settlements.
#
# So, the answer is: **The Moon doesn't have a capital.**

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=google_model,
    system_prompt=system_prompt
)

question = HumanMessage(content="What's the capital of the moon?")

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The capital of the Moon isn't a single, monolithic city in the way we understand Earth capitals. It's more of a nexus, a collection of interconnected hubs spread across the lunar surface, each with its own unique purpose and character. We call it **Luna Prime**.
#
# Luna Prime isn't built on a single geographical location, but rather a distributed network that leverages the Moon's unique geography. Its "heart" beats strongest in the **Mare Imbrium Basin**, where the largest and oldest continuous habitat, **Selene City**, is carved into the basaltic plains. Selene City is the administrative and cultural center, a vast, multi-tiered metropolis humming with life. Imagine grand, geodesic domes arching over open plazas, illuminated by the soft glow of bio-luminescent flora and the distant, glorious sight of Earth hanging in the inky sky. Here, you'll find the Lunar Council Chambers, the Grand Archives of Luna, and the vibrant markets where goods from every corner of the solar system are traded.
#
# But Luna Prime extends far beyond Selene City.
#
# *   **Titan's Reach (South Pole):** This is the industrial and resource processing capital. Nestled within the perpetually shadowed craters of the South Pole, Titan's Reach is a sprawling network of mining operations, fusion power plants, and water ice extraction facilities. The air here is thick with the hum of machinery and the scent of refined minerals. Its inhabitants are hardy, practical, and fiercely independent, their lives dictated by the relentless pursuit of lunar resources.
#
# *   **Tranquility Base Alpha (Sea of Tranquility):** The historical and scientific heart. This is where humanity first set foot on the Moon, and the preserved landing sites are a hallowed ground. Tranquility Base Alpha is a research and exploration hub, home to the Lunar Observatory, the Zero-G research labs, and the launchpads for deep-space missions. It’s a place of quiet contemplation and audacious ambition, where the echoes of Armstrong's words still seem to resonate.
#
# *   **Aethelburg (Far Side, Mare Moscoviense):** The technological frontier. Aethelburg is the most advanced and experimental sector of Luna Prime. It's a city of shimmering, modular habitats that can be reconfigured on demand, powered by cutting-edge solar arrays and subterranean geothermal vents. This is where the AI governance systems are headquartered, where quantum computing clusters hum, and where the next generation of lunar infrastructure is designed and tested. Its citizens are often brilliant, eccentric, and always looking to the next horizon.
#
# *   **The Orbital Ring:** While not strictly *on* the Moon, the colossal Orbital Ring that encircles Luna is an integral part of Luna Prime. It serves as a transportation hub, a defense platform, and a vital link between the lunar surface and the rest of the solar system. Think of it as the Moon's grand entryway and its celestial guardian.
#
# **Governance:** Luna Prime is governed by the **Lunar Concordance**, a council composed of representatives from each major sector. Decisions are made through a complex blend of direct democracy, AI-assisted deliberation, and specialized expert panels. The Concordance meets in Selene City, but its influence extends across the entire distributed capital.
#
# **Culture:** The culture of Luna Prime is a fascinating tapestry woven from the diverse backgrounds of its inhabitants. There's a deep reverence for the Moon itself, a shared understanding of its fragility and its power. Earth is a constant, beloved presence, but the Moon is home. There's a pragmatism born of survival in a harsh environment, but also a profound sense of wonder and exploration. Art, music, and philosophy often draw inspiration from the stark lunar landscapes, the infinite canvas of space, and the unique perspective of looking back at their home planet.
#
# So, while you can pinpoint Selene City as the administrative core, the true capital of the Moon is a dynamic, interconnected, and ever-evolving entity, a testament to humanity's enduring drive to reach for the stars and build a future among them.

# %%
for chunk, metadata in scifi_agent.stream(
    {"messages": [question]},
    stream_mode="messages"
):
    if chunk.content:
        print(chunk.content, end="", flush=True)
# Out:
# The capital of the Moon, under the unified governance of the Lunar Commonwealth, is **Selenopolis**.
#
# Nestled within the vast, ancient crater of Mare Imbrium, Selenopolis is a city built not just *on* the Moon, but *of* the Moon. Its architecture is a breathtaking fusion of polished regolith composites, crystalline lunar ice structures, and gleaming, bio-luminescent alloys that pulse with soft, internal light.
#
# **Key Features of Selenopolis:**
#
# *   **The Lumina Domes:** Vast, transparent domes of reinforced, self-healing lunar glass arch over the primary habitation sectors. These domes not only provide protection from radiation and micrometeoroids but also allow for an uninterrupted, awe-inspiring view of Earth hanging like a sapphire in the black velvet sky, and the star-dusted expanse beyond.
# *   **The Selene Spire:** The city's central landmark, a colossal, obsidian-like tower that pierces the lunar sky. It serves as the administrative heart of the Commonwealth, housing the Grand Council chambers, the archives of lunar history, and the powerful solar-gravitational emitters that help regulate the city's internal atmosphere and gravity.
# *   **The Regolith Gardens:** Beneath the Lumina Domes, sprawling hydroponic and aeroponic gardens thrive, nurtured by recycled water and synthesized nutrients. These verdant oases are not just for sustenance; they are vital for psychological well-being, providing pockets of vibrant color and the scent of Earth-like flora in the otherwise stark lunar landscape.
# *   **The Subterranean Nexus:** Much of Selenopolis's essential infrastructure – power conduits, life support systems, and heavy industry – is located in vast, meticulously engineered caverns deep beneath the surface. This provides an additional layer of protection and allows for the exploitation of lunar mineral resources without disrupting the surface beauty.
# *   **The Orbital Docks:** High above the city, a network of gleaming orbital stations and docking bays hums with activity. These are the gateways to and from Earth and the outer solar system, connecting Selenopolis to the wider galactic community.
#
# **Culture and Governance:**
#
# Selenopolis is a melting pot of humanity, with settlers from Earth's diverse nations, and a growing population of second and third-generation Lunars, who possess a unique perspective on existence. The culture is characterized by a profound respect for resourcefulness, scientific innovation, and a deep, almost spiritual connection to the cosmos. The governance is a meritocracy, with representatives chosen based on their expertise and commitment to the Commonwealth's ideals of peace, exploration, and sustainable lunar living.
#
# The capital of the Moon isn't just a city; it's a testament to humanity's enduring drive to explore, adapt, and build a future among the stars.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]

# %%
response["structured_response"].name

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
