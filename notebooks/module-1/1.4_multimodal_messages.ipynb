# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain_google_genai import ChatGoogleGenerativeAI
agent = create_agent(
    model=ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite"),
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The Moon, in its current state of semi-terraformed habitation, doesn't possess a single, monolithic capital in the traditional Earth sense. Instead, its governance is a distributed network, a tapestry woven from the primary lunar settlements. However, if one were to point to the most influential and historically significant hub, the undisputed nexus of lunar society, it would be **Artemis City**.
#
# Artemis City isn't a sprawling metropolis of towering skyscrapers, though it has its vertical elements. It's a city built *into* and *around* the lunar landscape, a testament to human ingenuity and adaptation. Its heart lies within the vast, geologically stable lava tube known as the **Mare Serenitatis Caverns**.
#
# **Here's a glimpse into Artemis City, the de facto capital of The Moon:**
#
# *   **Location:** Nestled within the Mare Serenitatis Caverns, a network of subterranean tunnels carved by ancient volcanic activity. The main ingress points are large, reinforced domes that mimic natural lunar craters, cleverly disguised and integrated into the regolith.
# *   **Architecture & Design:**
#     *   **Subterranean Majesty:** The primary living and working spaces are carved directly into the basaltic rock, creating a sense of immense, organic grandeur. Walls are often left in their natural, textured state, illuminated by a sophisticated system of artificial sunlight that mimics Earth's diurnal cycle, complete with simulated dawn and dusk.
#     *   **Bioluminescent Flora:** Vast hydroponic gardens, cultivated in cavernous chambers, provide not only sustenance but also a breathtaking, ethereal glow. Genetically engineered flora emits soft, shifting bioluminescence, creating vibrant, living art installations that perfume the air with subtle, earthy scents.
#     *   **Modular Habitation Units:** Residential and commercial spaces are often modular, prefabricated units that can be easily expanded, reconfigured, or relocated within the cavern system. These are often constructed from advanced composites and recycled lunar materials.
#     *   **Zero-G Parks:** Dedicated "gravity wells" – large, open caverns where artificial gravity can be precisely controlled – serve as recreational areas. Here, citizens can experience controlled zero-G acrobatics, sports, or simply float among sculpted lunar rock formations.
# *   **Governance & Administration:**
#     *   **The Lunar Council Chamber:** Located in the deepest, most secure part of the caverns, this is where representatives from the major lunar settlements convene. It's a circular amphitheater carved from obsidian-like rock, with holographic displays projecting real-time data from across the Moon.
#     *   **The Central Archives:** A repository of all lunar history, scientific data, and legal precedents, meticulously maintained and accessible to all citizens.
#     *   **The Orbital Command Center:** While physical governance happens underground, the strategic and defensive operations are managed from a heavily shielded facility integrated into the city's upper levels, with direct links to lunar orbital defense platforms.
# *   **Economy & Industry:**
#     *   **He-3 Refining:** The primary economic driver, with vast facilities extracting and processing Helium-3 for fusion power on Earth and other colonies.
#     *   **Advanced Manufacturing:** Artemis City is a hub for high-precision manufacturing, particularly for spacecraft components, advanced robotics, and specialized scientific equipment that benefits from the unique lunar environment.
#     *   **Tourism (Controlled):** While not open to mass tourism, curated expeditions to "surface wonders" and carefully managed "lunar heritage sites" contribute to the economy.
#     *   **Research & Development:** The city houses numerous research institutions focused on astrophysics, xenobotanics, lunar geology, and the long-term viability of human life beyond Earth.
# *   **Culture & Society:**
#     *   **"Lunar Grit":** A distinct cultural identity has emerged, characterized by resilience, pragmatism, and a deep respect for the lunar environment. There's a quiet pride in their pioneering spirit.
#     *   **Artistic Expression:** Art often draws inspiration from the stark beauty of the lunar landscape, the vastness of space, and the challenges of survival. Holographic sculptures, light-based installations, and sonic landscapes are popular.
#     *   **Community Focus:** Due to the enclosed environment, there's a strong emphasis on community and shared responsibility. Public spaces are designed for interaction and collaboration.
#     *   **"Earth-Gazing" Rituals:** Regular communal gatherings are held in specially designed observation domes, where citizens gather to watch Earth rise and set, a poignant reminder of their origins and their unique place in the cosmos.
#
# **Why Artemis City is the Capital:**
#
# *   **Historical Significance:** It was one of the earliest, most ambitious, and ultimately most successful permanent settlements, established during the initial wave of lunar colonization.
# *   **Concentration of Power:** The Lunar Council, the primary governing body, is headquartered here. Key administrative functions and diplomatic missions are based within its secure confines.
# *   **Economic Powerhouse:** Its He-3 refining capabilities and advanced manufacturing make it the economic engine of lunar society.
# *   **Symbolic Importance:** Artemis City represents the ultimate achievement of humanity's drive to conquer the void, a beacon of progress and a testament to their ability to thrive in the most challenging environments.
#
# While other settlements like the mining outposts on the far side, the orbital research stations, and the atmospheric processing facilities on the poles are vital, Artemis City remains the beating heart, the intellectual and political center, the undeniable capital of The Moon.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon.png', 'type': 'image/png', 'size': 358916, 'content': <memory at 0x000001D76A083400>, 'last_modified': datetime.datetime(2026, 3, 14, 7, 21, 57, 690000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Welcome to **Aethelburg**, the gleaming capital of the Xylos Federation, perched precariously on the rugged, windswept plains of Xylos Prime. Dominating the skyline are the **Spireward Towers**, impossibly tall structures that pierce the thin, cerulean atmosphere, their crystalline facets reflecting the pale, distant light of a binary sun system. These towers are not mere buildings; they are entire ecosystems, housing millions of Xylosians in vertically integrated arcologies. Each spire is a self-sustaining marvel, from the hydroponic farms that spiral around their lower levels to the research labs and residential districts that ascend towards the heavens.
#
# Beneath the spires, nestled within the protective embrace of the jagged, ochre mountains, lie the **Cerulean Pools**. These are not natural bodies of water, but vast, bio-luminescent energy conduits, harnessing the planet's geothermal and exotic particle energies to power the entire city. The soft, pulsating blue light emanating from them casts an ethereal glow on the surrounding rocky terrain, a stark contrast to the sharp, metallic lines of the city above.
#
# The landscape itself is a testament to Xylos Prime's harsh beauty. Towering, eroded rock formations, sculpted by millennia of solar winds and dust storms, surround the city, offering natural fortifications and a dramatic backdrop. The ground is a mosaic of mineral-rich soil and exposed bedrock, dotted with hardy, silicon-based flora that gleam with an inner luminescence. In the distance, the colossal, icy moon of Xylos Prime hangs in the sky, a constant, silent sentinel, its craters and frozen seas a stark reminder of the planet's volatile past and the technological prowess required to carve out a civilization here.
#
# Aethelburg is a city of contrasts: of raw, untamed nature and hyper-advanced technology, of the stark realities of its alien environment and the vibrant pulse of its inhabitants. It is a beacon of Xylosian ingenuity, a testament to their ability to thrive in the most challenging of cosmic frontiers.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
